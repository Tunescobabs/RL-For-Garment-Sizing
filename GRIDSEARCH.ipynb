# %% [markdown]
# ### GRID SEARCH ALGORITHM

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data from the csv file into a dataframe
df = pd.read_csv("armspan.csv")

# Define the state space and action space for the MDP
state_space = np.array(df['anthropometric_measurement'].unique())
action_space = np.array(df['garment_measurement'].unique())

# Define a function to train and evaluate the Q-learning model with a given set of hyperparameters
def train_eval_model(alpha, gamma, epsilon, num_iterations, df):
    # Split the data into training and test data
    X_train, X_test, y_train, y_test = train_test_split(df[['anthropometric_measurement', 'garment_measurement']], df['tolerance'], test_size=0.2, random_state=42)

    # Initialize the Q-Table
    q_table = pd.DataFrame(0.0, index=state_space, columns=action_space)

    for i in range(num_iterations):
        state = X_train['anthropometric_measurement'].sample(1).iloc[0] # select a random state from the training data
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(action_space) # select a random action from the action space
        else:
            action = q_table.loc[state, :].idxmax() # select the action with the highest Q-Value for the current state

        tolerance = y_train[(X_train['anthropometric_measurement'] == state) & (X_train['garment_measurement'] == action)].values

        if len(tolerance) == 0:
            continue
        else:
            reward = np.abs(tolerance[0] - q_table.loc[state, action]) # calculate the reward based on the difference between the actual tolerance and the predicted tolerance
            q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value

    # Use the Q-Table to make predictions on the test data
    y_pred = []
    for i in X_test.index:
        state = X_test.loc[i, 'anthropometric_measurement']
        action = q_table.loc[state, :].idxmax()
        y_pred.append(q_table.loc[state, action])

    # Calculate the evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return {'alpha': alpha, 'gamma': gamma, 'epsilon': epsilon, 'num_iterations': num_iterations, 'mse': mse, 'r2': r2}

# Define the hyperparameter grid
param_grid = {'alpha': [0.1, 0.5, 0.9], 'gamma': [0.1, 0.5, 0.9], 'epsilon': [0.1, 0.5,0.9], 'num_iterations': [10000, 50000, 100000]}

# Generate all combinations of hyperparameters
param_list = list(ParameterGrid(param_grid))

# Train and evaluate the model for each set of hyperparameters
results = []
for params in param_list:
    result = train_eval_model(params['alpha'], params['gamma'], params['epsilon'], params['num_iterations'], df)
    result.update({'params':params})
    results.append(result)

# Print the evaluation results for each set of hyperparameters
for result in results:
    print("Parameters: ", result['params'])
    print("Mean Squared Error: ", result['mse'])
    print("R-squared: ", result['r2'])
    print()
    
# Find the optimal combination of hyperparameters based on the minimum MSE value
optimal_result = min(results, key=lambda x: x['mse'])
optimal_params = optimal_result['params']
print("Optimal combination of hyperparameters:")
print("Alpha:", optimal_params['alpha'])
print("Gamma:", optimal_params['gamma'])
print("Epsilon:", optimal_params['epsilon'])
print("Num Iterations:", optimal_params['num_iterations'])

# Save the results in a dataframe
hyperparameters_combinations = pd.DataFrame(results)

# save into csv file
# hyperparameters_combinations.to_csv('hyperparameters.csv', index=False)
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_14544\2185505023.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_14544\2185505023.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data from the csv file into a dataframe
df = pd.read_csv("sleeve_length.csv")

# Define the state space and action space for the MDP
state_space = np.array(df['anthropometric_measurement'].unique())
action_space = np.array(df['garment_measurement'].unique())

# Define a function to train and evaluate the Q-learning model with a given set of hyperparameters
def train_eval_model(alpha, gamma, epsilon, num_iterations, df):
    # Split the data into training and test data
    X_train, X_test, y_train, y_test = train_test_split(df[['anthropometric_measurement', 'garment_measurement']], df['tolerance'], test_size=0.2, random_state=42)

    # Initialize the Q-Table
    q_table = pd.DataFrame(0.0, index=state_space, columns=action_space)

    for i in range(num_iterations):
        state = X_train['anthropometric_measurement'].sample(1).iloc[0] # select a random state from the training data
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(action_space) # select a random action from the action space
        else:
            action = q_table.loc[state, :].idxmax() # select the action with the highest Q-Value for the current state

        tolerance = y_train[(X_train['anthropometric_measurement'] == state) & (X_train['garment_measurement'] == action)].values

        if len(tolerance) == 0:
            continue
        else:
            reward = np.abs(tolerance[0] - q_table.loc[state, action]) # calculate the reward based on the difference between the actual tolerance and the predicted tolerance
            q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value

    # Use the Q-Table to make predictions on the test data
    y_pred = []
    for i in X_test.index:
        state = X_test.loc[i, 'anthropometric_measurement']
        action = q_table.loc[state, :].idxmax()
        y_pred.append(q_table.loc[state, action])

    # Calculate the evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return {'alpha': alpha, 'gamma': gamma, 'epsilon': epsilon, 'num_iterations': num_iterations, 'mse': mse, 'r2': r2}

# Define the hyperparameter grid
param_grid = {'alpha': [0.1, 0.5, 0.9], 'gamma': [0.1, 0.5, 0.9], 'epsilon': [0.1, 0.5,0.9], 'num_iterations': [10000, 20000, 40000]}

# Generate all combinations of hyperparameters
param_list = list(ParameterGrid(param_grid))

# Train and evaluate the model for each set of hyperparameters
results = []
for params in param_list:
    result = train_eval_model(params['alpha'], params['gamma'], params['epsilon'], params['num_iterations'], df)
    result.update({'params':params})
    results.append(result)

# Print the evaluation results for each set of hyperparameters
for result in results:
    print("Parameters: ", result['params'])
    print("Mean Squared Error: ", result['mse'])
    print("R-squared: ", result['r2'])
    print()
    
# Find the optimal combination of hyperparameters based on the minimum MSE value
optimal_result = min(results, key=lambda x: x['mse'])
optimal_params = optimal_result['params']
print("Optimal combination of hyperparameters:")
print("Alpha:", optimal_params['alpha'])
print("Gamma:", optimal_params['gamma'])
print("Epsilon:", optimal_params['epsilon'])
print("Num Iterations:", optimal_params['num_iterations'])
\
]


# Save the results in a dataframe
hyperparameters_combinations = pd.DataFrame(results)

# save into csv file
# hyperparameters_combinations.to_csv('hyperparameters.csv', index=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\251822639.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  55.125808443281066
# R-squared:  -0.4172607221470699
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  40.27100974005576
# R-squared:  -0.03535026437765665
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  38.96408453222203
# R-squared:  -0.0017497818422862466
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  44.18006297804331
# R-squared:  -0.13585033451598094
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  50.439390687925176
# R-squared:  -0.29677494606865884
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  53.97454889003432
# R-squared:  -0.38766233634757663
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  68.80871877680637
# R-squared:  -0.769042436157094
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  45.05316652842759
# R-squared:  -0.15829744963811065
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  71.32377232737906
# R-squared:  -0.8337033765039499
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  38.76684130702656
# R-squared:  0.003321256273495332
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  40.18793757899844
# R-squared:  -0.03321451500190742
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  37.404670786688214
# R-squared:  0.03834207192880701
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  47.86499309703089
# R-squared:  -0.2305882960802319
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  44.55391902116218
# R-squared:  -0.1454620118883838
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  3.0379094086955784e+73
# R-squared:  -7.810333859892886e+71
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  1.1261935680253917e+139
# R-squared:  -2.8953950147312382e+137
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  3.5818687916282775e+62
# R-squared:  -9.20882993576828e+60
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  1.8397718017404232e+131
# R-squared:  -4.729973828870444e+129
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  2.40809319115774e+285
# R-squared:  -6.191103571041845e+283
#
# Optimal combination of hyperparameters:
# Alpha: 0.9
# Gamma: 0.5
# Epsilon: 0.1
# Num Iterations: 10000

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data from the csv file into a dataframe
df = pd.read_csv("sleeve_width.csv")

# Define the state space and action space for the MDP
state_space = np.array(df['anthropometric_measurement'].unique())
action_space = np.array(df['garment_measurement'].unique())

# Define a function to train and evaluate the Q-learning model with a given set of hyperparameters
def train_eval_model(alpha, gamma, epsilon, num_iterations, df):
    # Split the data into training and test data
    X_train, X_test, y_train, y_test = train_test_split(df[['anthropometric_measurement', 'garment_measurement']], df['tolerance'], test_size=0.2, random_state=42)

    # Initialize the Q-Table
    q_table = pd.DataFrame(0.0, index=state_space, columns=action_space)

    for i in range(num_iterations):
        state = X_train['anthropometric_measurement'].sample(1).iloc[0] # select a random state from the training data
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(action_space) # select a random action from the action space
        else:
            action = q_table.loc[state, :].idxmax() # select the action with the highest Q-Value for the current state

        tolerance = y_train[(X_train['anthropometric_measurement'] == state) & (X_train['garment_measurement'] == action)].values

        if len(tolerance) == 0:
            continue
        else:
            reward = np.abs(tolerance[0] - q_table.loc[state, action]) # calculate the reward based on the difference between the actual tolerance and the predicted tolerance
            q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value

    # Use the Q-Table to make predictions on the test data
    y_pred = []
    for i in X_test.index:
        state = X_test.loc[i, 'anthropometric_measurement']
        action = q_table.loc[state, :].idxmax()
        y_pred.append(q_table.loc[state, action])

    # Calculate the evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return {'alpha': alpha, 'gamma': gamma, 'epsilon': epsilon, 'num_iterations': num_iterations, 'mse': mse, 'r2': r2}

# Define the hyperparameter grid
param_grid = {'alpha': [0.1, 0.5, 0.9], 'gamma': [0.1, 0.5, 0.9], 'epsilon': [0.1, 0.5,0.9], 'num_iterations': [20000, 50000, 100000]}

# Generate all combinations of hyperparameters
param_list = list(ParameterGrid(param_grid))

# Train and evaluate the model for each set of hyperparameters
results = []
for params in param_list:
    result = train_eval_model(params['alpha'], params['gamma'], params['epsilon'], params['num_iterations'], df)
    result.update({'params':params})
    results.append(result)

# Print the evaluation results for each set of hyperparameters
for result in results:
    print("Parameters: ", result['params'])
    print("Mean Squared Error: ", result['mse'])
    print("R-squared: ", result['r2'])
    print()
    
# Find the optimal combination of hyperparameters based on the minimum MSE value
optimal_result = min(results, key=lambda x: x['mse'])
optimal_params = optimal_result['params']
print("Optimal combination of hyperparameters:")
print("Alpha:", optimal_params['alpha'])
print("Gamma:", optimal_params['gamma'])
print("Epsilon:", optimal_params['epsilon'])
print("Num Iterations:", optimal_params['num_iterations'])

# Save the results in a dataframe
hyperparameters_combinations = pd.DataFrame(results)

# save into csv file
# hyperparameters_combinations.to_csv('hyperparameters.csv', index=False)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data from the csv file into a dataframe
df = pd.read_csv("bust.csv")

# Define the state space and action space for the MDP
state_space = np.array(df['anthropometric_measurement'].unique())
action_space = np.array(df['garment_measurement'].unique())

# Define a function to train and evaluate the Q-learning model with a given set of hyperparameters
def train_eval_model(alpha, gamma, epsilon, num_iterations, df):
    # Split the data into training and test data
    X_train, X_test, y_train, y_test = train_test_split(df[['anthropometric_measurement', 'garment_measurement']], df['tolerance'], test_size=0.2, random_state=42)

    # Initialize the Q-Table
    q_table = pd.DataFrame(0.0, index=state_space, columns=action_space)

    for i in range(num_iterations):
        state = X_train['anthropometric_measurement'].sample(1).iloc[0] # select a random state from the training data
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(action_space) # select a random action from the action space
        else:
            action = q_table.loc[state, :].idxmax() # select the action with the highest Q-Value for the current state

        tolerance = y_train[(X_train['anthropometric_measurement'] == state) & (X_train['garment_measurement'] == action)].values

        if len(tolerance) == 0:
            continue
        else:
            reward = np.abs(tolerance[0] - q_table.loc[state, action]) # calculate the reward based on the difference between the actual tolerance and the predicted tolerance
            q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value

    # Use the Q-Table to make predictions on the test data
    y_pred = []
    for i in X_test.index:
        state = X_test.loc[i, 'anthropometric_measurement']
        action = q_table.loc[state, :].idxmax()
        y_pred.append(q_table.loc[state, action])

    # Calculate the evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return {'alpha': alpha, 'gamma': gamma, 'epsilon': epsilon, 'num_iterations': num_iterations, 'mse': mse, 'r2': r2}

# Define the hyperparameter grid
param_grid = {'alpha': [0.1, 0.5, 0.9], 'gamma': [0.1, 0.5, 0.9], 'epsilon': [0.1, 0.5,0.9], 'num_iterations': [10000, 20000, 40000]}

# Generate all combinations of hyperparameters
param_list = list(ParameterGrid(param_grid))

# Train and evaluate the model for each set of hyperparameters
results = []
for params in param_list:
    result = train_eval_model(params['alpha'], params['gamma'], params['epsilon'], params['num_iterations'], df)
    result.update({'params':params})
    results.append(result)

# Print the evaluation results for each set of hyperparameters
for result in results:
    print("Parameters: ", result['params'])
    print("Mean Squared Error: ", result['mse'])
    print("R-squared: ", result['r2'])
    print()
    
# Find the optimal combination of hyperparameters based on the minimum MSE value
optimal_result = min(results, key=lambda x: x['mse'])
optimal_params = optimal_result['params']
print("Optimal combination of hyperparameters:")
print("Alpha:", optimal_params['alpha'])
print("Gamma:", optimal_params['gamma'])
print("Epsilon:", optimal_params['epsilon'])
print("Num Iterations:", optimal_params['num_iterations'])

# Save the results in a dataframe
hyperparameters_combinations = pd.DataFrame(results)

# save into csv file
# hyperparameters_combinations.to_csv('hyperparameters.csv', index=False)
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5424\1957732851.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5424\1957732851.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5424\1957732851.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5424\1957732851.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  336.0709374709788
# R-squared:  -3.688417495306135
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  295.78444196229776
# R-squared:  -3.1263935613449227
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  242.14551782682875
# R-squared:  -2.3780941926503356
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  373.7630971450067
# R-squared:  -4.214248684939559
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  332.64958500077546
# R-squared:  -3.640687308043824
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  171.7850335653979
# R-squared:  -1.396517719921298
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  351.53699165042855
# R-squared:  -3.9041794399239924
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  248.1713502471059
# R-squared:  -2.4621586415301198
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  265.939988247553
# R-squared:  -2.710043192024021
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  1.6653930209632354e+162
# R-squared:  -2.323336208361971e+160
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  2.242222177382299e+148
# R-squared:  -3.1280520011375235e+146
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  2.542963987987603e+292
# R-squared:  -3.5476072227293075e+290
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  136.71592035315922
# R-squared:  -0.9072798073352695
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  118.03850959163594
# R-squared:  -0.6467172605101466
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  118.78594709505458
# R-squared:  -0.6571445205822213
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  4020970149.8307457
# R-squared:  -56095259.543611124
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  3.8164559350221025e+33
# R-squared:  -5.324214854897327e+31
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  8.383567150247141e+70
# R-squared:  -1.1695644733840371e+69
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  5.417841904520618e+30
# R-squared:  -7.558256885616796e+28
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  1.9061188528501773e+73
# R-squared:  -2.65916506946018e+71
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  8.809285512316534e+145
# R-squared:  -1.2289550720421423e+144
# Optimal combination of hyperparameters:
# Alpha: 0.1
# Gamma: 0.9
# Epsilon: 0.9
# Num Iterations: 40000

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data from the csv file into a dataframe
df = pd.read_csv("wrapper_length.csv")

# Define the state space and action space for the MDP
state_space = np.array(df['anthropometric_measurement'].unique())
action_space = np.array(df['garment_measurement'].unique())

# Define a function to train and evaluate the Q-learning model with a given set of hyperparameters
def train_eval_model(alpha, gamma, epsilon, num_iterations, df):
    # Split the data into training and test data
    X_train, X_test, y_train, y_test = train_test_split(df[['anthropometric_measurement', 'garment_measurement']], df['tolerance'], test_size=0.2, random_state=42)

    # Initialize the Q-Table
    q_table = pd.DataFrame(0.0, index=state_space, columns=action_space)

    for i in range(num_iterations):
        state = X_train['anthropometric_measurement'].sample(1).iloc[0] # select a random state from the training data
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(action_space) # select a random action from the action space
        else:
            action = q_table.loc[state, :].idxmax() # select the action with the highest Q-Value for the current state

        tolerance = y_train[(X_train['anthropometric_measurement'] == state) & (X_train['garment_measurement'] == action)].values

        if len(tolerance) == 0:
            continue
        else:
            reward = np.abs(tolerance[0] - q_table.loc[state, action]) # calculate the reward based on the difference between the actual tolerance and the predicted tolerance
            q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value

    # Use the Q-Table to make predictions on the test data
    y_pred = []
    for i in X_test.index:
        state = X_test.loc[i, 'anthropometric_measurement']
        action = q_table.loc[state, :].idxmax()
        y_pred.append(q_table.loc[state, action])

    # Calculate the evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return {'alpha': alpha, 'gamma': gamma, 'epsilon': epsilon, 'num_iterations': num_iterations, 'mse': mse, 'r2': r2}

# Define the hyperparameter grid
param_grid = {'alpha': [0.1, 0.5, 0.9], 'gamma': [0.1, 0.5, 0.9], 'epsilon': [0.1, 0.5,0.9], 'num_iterations': [10000, 20000, 40000]}

# Generate all combinations of hyperparameters
param_list = list(ParameterGrid(param_grid))

# Train and evaluate the model for each set of hyperparameters
results = []
for params in param_list:
    result = train_eval_model(params['alpha'], params['gamma'], params['epsilon'], params['num_iterations'], df)
    result.update({'params':params})
    results.append(result)

# Print the evaluation results for each set of hyperparameters
for result in results:
    print("Parameters: ", result['params'])
    print("Mean Squared Error: ", result['mse'])
    print("R-squared: ", result['r2'])
    print()
    
# Find the optimal combination of hyperparameters based on the minimum MSE value
optimal_result = min(results, key=lambda x: x['mse'])
optimal_params = optimal_result['params']
print("Optimal combination of hyperparameters:")
print("Alpha:", optimal_params['alpha'])
print("Gamma:", optimal_params['gamma'])
print("Epsilon:", optimal_params['epsilon'])
print("Num Iterations:", optimal_params['num_iterations'])

# Save the results in a dataframe
hyperparameters_combinations = pd.DataFrame(results)

# save into csv file
# hyperparameters_combinations.to_csv('hyperparameters.csv', index=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4228
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  1.9592731450652393e+19
# R-squared:  -2.0935365918938874e+17
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  5.756486637132415e+65
# R-squared:  -6.150962384156812e+63
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  1.1923907398298066e+35
# R-squared:  -1.2741019045539986e+33
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  4.7464864574306696e+79
# R-squared:  -5.071749748924884e+77
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  1.1921984693478902e+171
# R-squared:  -1.2738964583197934e+169
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  3033556969609.7476
# R-squared:  -32414380482.234104
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  371.79579939221134
# R-squared:  -2.9727391390041005
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  286.0773841667619
# R-squared:  -2.05681458134036
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  562.5138803195601
# R-squared:  -5.010613654677562
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  2.19850737307701e+181
# R-squared:  -2.349164864877464e+179
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  68414009105.63027
# R-squared:  -731022275.4066386
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  2.025822885663857e+20
# R-squared:  -2.164646797979835e+18
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  6.296654296378971e+16
# R-squared:  -672814620522769.1
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  3.843322864619687e+162
# R-squared:  -4.106694909696133e+160
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  1.509146836686879e+145
# R-squared:  -1.6125644007842955e+143
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  5.922303622318992e+301
# R-squared:  -6.328142338325002e+299
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  11110.571509598945
# R-squared:  -117.71947548908287
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  76949.51780947157
# R-squared:  -821.2265061329922
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  29734679009.35039
# R-squared:  -317723123.57343113
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  1.9320917347453406e+31
# R-squared:  -2.064492516407365e+29
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  5.23129551366288e+86
# R-squared:  -5.589781398498621e+84
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  2.2199113833975635e+153
# R-squared:  -2.372035631484057e+151
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  6.71432358751623e+70
# R-squared:  -7.174437191509308e+68
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  3.1082635232990856e+160
# R-squared:  -3.3212640308296456e+158
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  2.821695113647423e+301
# R-squared:  -3.0150578986230944e+299
#
# Optimal combination of hyperparameters:
# Alpha: 0.1
# Gamma: 0.9
# Epsilon: 0.9
# Num Iterations: 10000

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data from the csv file into a dataframe
df = pd.read_csv("sleeve_width.csv")

# Define the state space and action space for the MDP
state_space = np.array(df['anthropometric_measurement'].unique())
action_space = np.array(df['garment_measurement'].unique())

# Define a function to train and evaluate the Q-learning model with a given set of hyperparameters
def train_eval_model(alpha, gamma, epsilon, num_iterations, df):
    # Split the data into training and test data
    X_train, X_test, y_train, y_test = train_test_split(df[['anthropometric_measurement', 'garment_measurement']], df['tolerance'], test_size=0.2, random_state=42)

    # Initialize the Q-Table
    q_table = pd.DataFrame(0.0, index=state_space, columns=action_space)

    for i in range(num_iterations):
        state = X_train['anthropometric_measurement'].sample(1).iloc[0] # select a random state from the training data
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(action_space) # select a random action from the action space
        else:
            action = q_table.loc[state, :].idxmax() # select the action with the highest Q-Value for the current state

        tolerance = y_train[(X_train['anthropometric_measurement'] == state) & (X_train['garment_measurement'] == action)].values

        if len(tolerance) == 0:
            continue
        else:
            reward = np.abs(tolerance[0] - q_table.loc[state, action]) # calculate the reward based on the difference between the actual tolerance and the predicted tolerance
            q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value

    # Use the Q-Table to make predictions on the test data
    y_pred = []
    for i in X_test.index:
        state = X_test.loc[i, 'anthropometric_measurement']
        action = q_table.loc[state, :].idxmax()
        y_pred.append(q_table.loc[state, action])

    # Calculate the evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return {'alpha': alpha, 'gamma': gamma, 'epsilon': epsilon, 'num_iterations': num_iterations, 'mse': mse, 'r2': r2}

# Define the hyperparameter grid
param_grid = {'alpha': [0.1, 0.5, 0.9], 'gamma': [0.1, 0.5, 0.9], 'epsilon': [0.1, 0.5,0.9], 'num_iterations': [10000, 20000, 40000]}

# Generate all combinations of hyperparameters
param_list = list(ParameterGrid(param_grid))

# Train and evaluate the model for each set of hyperparameters
results = []
for params in param_list:
    result = train_eval_model(params['alpha'], params['gamma'], params['epsilon'], params['num_iterations'], df)
    result.update({'params':params})
    results.append(result)

# Print the evaluation results for each set of hyperparameters
for result in results:
    print("Parameters: ", result['params'])
    print("Mean Squared Error: ", result['mse'])
    print("R-squared: ", result['r2'])
    print()
    
# Find the optimal combination of hyperparameters based on the minimum MSE value
optimal_result = min(results, key=lambda x: x['mse'])
optimal_params = optimal_result['params']
print("Optimal combination of hyperparameters:")
print("Alpha:", optimal_params['alpha'])
print("Gamma:", optimal_params['gamma'])
print("Epsilon:", optimal_params['epsilon'])
print("Num Iterations:", optimal_params['num_iterations'])

# Save the results in a dataframe
hyperparameters_combinations = pd.DataFrame(results)

# save into csv file
# hyperparameters_combinations.to_csv('hyperparameters.csv', index=False)
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\953404536.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  255.0690778866863
# R-squared:  -3.252982012880077
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  185.8793356116241
# R-squared:  -2.0993230440638997
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  187.2849271736218
# R-squared:  -2.1227596584907094
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  213.91488753801022
# R-squared:  -2.5667834632255477
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  245.12781362032862
# R-squared:  -3.0872229233800574
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  116.4666917767559
# R-squared:  -0.9419474494130569
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  179.26000140152846
# R-squared:  -1.9889532980875368
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  158.82415913584387
# R-squared:  -1.6482092522231384
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  104.31010930404172
# R-squared:  -0.7392504897388035
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  122.79432971921841
# R-squared:  -1.047453497328696
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  118.48547773049766
# R-squared:  -0.975608371467015
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  111.9290273454313
# R-squared:  -0.8662871405790611
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  172.9483245592864
# R-squared:  -1.8837133830669783
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  139.10735719546727
# R-squared:  -1.3194543725697403
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  74.93053457234306
# R-squared:  -0.24938004399433966
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  123.9540985638541
# R-squared:  -1.0667913021155448
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  44.27352595354866
# R-squared:  0.26179013509873184
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  6.39655928369619e+48
# R-squared:  -1.066552316073627e+47
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  133.6188108878797
# R-squared:  -1.227939207672335
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  110.41626635323925
# R-squared:  -0.8410635997920528
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  108.67100597399194
# R-squared:  -0.8119634004961251
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  71.32196554484817
# R-squared:  -0.1892113269811786
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  78.37635356043161
# R-squared:  -0.3068350922401002
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  60.69284909191552
# R-squared:  -0.011983097429917322
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  613.4387967641735
# R-squared:  -9.228382798325098
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  36841160816.75265
# R-squared:  -614283767.0892
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  5.139272693093213e+23
# R-squared:  -8.569143113741603e+21
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  294.9042283978197
# R-squared:  -3.9171870980589416
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  171.88278259315524
# R-squared:  -1.865946702552542
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  127.51682780806004
# R-squared:  -1.1261956937333362
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  208.16609318996416
# R-squared:  -2.470928963101279
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  230.2420788530466
# R-squared:  -2.83902050410492
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  61.2436559139785
# R-squared:  -0.021167164452914777
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:
# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data from the csv file into a dataframe
df = pd.read_csv("sleeve_width.csv")

# Define the state space and action space for the MDP
state_space = np.array(df['anthropometric_measurement'].unique())
action_space = np.array(df['garment_measurement'].unique())

# Define a function to train and evaluate the Q-learning model with a given set of hyperparameters
def train_eval_model(alpha, gamma, epsilon, num_iterations, df):
    # Split the data into training and test data
    X_train, X_test, y_train, y_test = train_test_split(df[['anthropometric_measurement', 'garment_measurement']], df['tolerance'], test_size=0.2, random_state=42)

    # Initialize the Q-Table
    q_table = pd.DataFrame(0.0, index=state_space, columns=action_space, dtype=np.float64)

    for i in range(num_iterations):
        state = X_train['anthropometric_measurement'].sample(1).iloc[0] # select a random state from the training data
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(action_space) # select a random action from the action space
        else:
            action = q_table.loc[state, :].idxmax() # select the action with the highest Q-Value for the current state

        tolerance = y_train[(X_train['anthropometric_measurement'] == state) & (X_train['garment_measurement'] == action)].values

        if len(tolerance) == 0:
            continue
        else:
            reward = np.abs(tolerance[0] - q_table.loc[state, action].astype(float)) # calculate the reward based on the difference between the actual tolerance and the predicted tolerance
            q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value

    # Use the Q-Table to make predictions on the test data
    y_pred = []
    for i in X_test.index:
        state = X_test.loc[i, 'anthropometric_measurement']
        action = q_table.loc[state, :].idxmax()
        y_pred.append(q_table.loc[state, action])

    # Calculate the evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return {'alpha': alpha, 'gamma': gamma, 'epsilon': epsilon, 'num_iterations': num_iterations, 'mse': mse, 'r2': r2}

# Define the hyperparameter grid
param_grid = {'alpha': [0.1, 0.5, 0.9], 'gamma': [0.1, 0.5, 0.9], 'epsilon': [0.1, 0.5,0.9], 'num_iterations': [10000, 20000, 40000]}

# Generate all combinations of hyperparameters
param_list = list(ParameterGrid(param_grid))

# Train and evaluate the model for each set of hyperparameters
results = []
for params in param_list:
    result = train_eval_model(params['alpha'], params['gamma'], params['epsilon'], params['num_iterations'], df)
    result.update({'params':params})
    results.append(result)

# Print the evaluation results for each set of hyperparameters
for result in results:
    print("Parameters: ", result['params'])
    print("Mean Squared Error: ", result['mse'])
    print("R-squared: ", result['r2'])
    print()
    
# Find the optimal combination of hyperparameters based on the minimum MSE value
optimal_result = min(results, key=lambda x: x['mse'])
optimal_params = optimal_result['params']
print("Optimal combination of hyperparameters:")
print("Alpha:", optimal_params['alpha'])
print("Gamma:", optimal_params['gamma'])
print("Epsilon:", optimal_params['epsilon'])
print("Num Iterations:", optimal_params['num_iterations'])

# Save the results in a dataframe
hyperparameters_combinations = pd.DataFrame(results)

# save into csv file
# hyperparameters_combinations.to_csv('hyperparameters.csv', index=False)
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_4228\1102991257.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  308.6824255188344
# R-squared:  -4.146922607400548
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  229.0332070413775
# R-squared:  -2.8188639641060163
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  168.8240875871516
# R-squared:  -1.8149464991911661
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  207.86220776523254
# R-squared:  -2.465862024936653
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  238.44977825171614
# R-squared:  -2.975874403444202
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  156.38272401433701
# R-squared:  -1.6075011438808358
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  331.8699351014364
# R-squared:  -4.533547524836053
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  228.6835296858206
# R-squared:  -2.813033498430535
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  138.367427352706
# R-squared:  -1.307116897803572
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  128.94393222468562
# R-squared:  -1.14999101014212
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  7.882801048996523e+35
# R-squared:  -1.3143659494228455e+34
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  2.104820055228181e+81
# R-squared:  -3.5095441240476423e+79
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  5.129484062768417e+157
# R-squared:  -8.552821704244612e+155
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  4.524944644027219e+73
# R-squared:  -7.544822108493732e+71
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  3.491695969259164e+145
# R-squared:  -5.8219993872805754e+143
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  inf
# R-squared:  -inf
# Optimal combination of hyperparameters:
# Alpha: 0.1
# Gamma: 0.9
# Epsilon: 0.5
# Num Iterations: 10000

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data from the csv file into a dataframe
df = pd.read_csv("top_length.csv")

# Define the state space and action space for the MDP
state_space = np.array(df['anthropometric_measurement'].unique())
action_space = np.array(df['garment_measurement'].unique())

# Define a function to train and evaluate the Q-learning model with a given set of hyperparameters
def train_eval_model(alpha, gamma, epsilon, num_iterations, df):
    # Split the data into training and test data
    X_train, X_test, y_train, y_test = train_test_split(df[['anthropometric_measurement', 'garment_measurement']], df['tolerance'], test_size=0.2, random_state=42)

    # Initialize the Q-Table
    q_table = pd.DataFrame(0.0, index=state_space, columns=action_space, dtype=np.float64)

    for i in range(num_iterations):
        state = X_train['anthropometric_measurement'].sample(1).iloc[0] # select a random state from the training data
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(action_space) # select a random action from the action space
        else:
            action = q_table.loc[state, :].idxmax() # select the action with the highest Q-Value for the current state

        tolerance = y_train[(X_train['anthropometric_measurement'] == state) & (X_train['garment_measurement'] == action)].values

        if len(tolerance) == 0:
            continue
        else:
            reward = np.abs(tolerance[0] - q_table.loc[state, action].astype(float)) # calculate the reward based on the difference between the actual tolerance and the predicted tolerance
            q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value

    # Use the Q-Table to make predictions on the test data
    y_pred = []
    for i in X_test.index:
        state = X_test.loc[i, 'anthropometric_measurement']
        action = q_table.loc[state, :].idxmax()
        y_pred.append(q_table.loc[state, action])

    # Calculate the evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return {'alpha': alpha, 'gamma': gamma, 'epsilon': epsilon, 'num_iterations': num_iterations, 'mse': mse, 'r2': r2}

# Define the hyperparameter grid
param_grid = {'alpha': [0.1, 0.5, 0.9], 'gamma': [0.1, 0.5, 0.9], 'epsilon': [0.1, 0.5,0.9], 'num_iterations': [10000, 20000, 40000]}

# Generate all combinations of hyperparameters
param_list = list(ParameterGrid(param_grid))

# Train and evaluate the model for each set of hyperparameters
results = []
for params in param_list:
    result = train_eval_model(params['alpha'], params['gamma'], params['epsilon'], params['num_iterations'], df)
    result.update({'params':params})
    results.append(result)

# Print the evaluation results for each set of hyperparameters
for result in results:
    print("Parameters: ", result['params'])
    print("Mean Squared Error: ", result['mse'])
    print("R-squared: ", result['r2'])
    print()
    
# Find the optimal combination of hyperparameters based on the minimum MSE value
optimal_result = min(results, key=lambda x: x['mse'])
optimal_params = optimal_result['params']
print("Optimal combination of hyperparameters:")
print("Alpha:", optimal_params['alpha'])
print("Gamma:", optimal_params['gamma'])
print("Epsilon:", optimal_params['epsilon'])
print("Num Iterations:", optimal_params['num_iterations'])

# Save the results in a dataframe
hyperparameters_combinations = pd.DataFrame(results)

# save into csv file
# hyperparameters_combinations.to_csv('hyperparameters.csv', index=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\961754543.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\961754543.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\961754543.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5260\961754543.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5260
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  90.9532669109106
# R-squared:  -1.3316958224306608
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  159.37422939068423
# R-squared:  -3.0857490609695333
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  101.41007168458783
# R-squared:  -1.5997685243231463
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  45.74512544802868
# R-squared:  -0.17273102469439494
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  85.46415209854561
# R-squared:  -1.1909757965148202
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  79.87784916433631
# R-squared:  -1.0477642368103561
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  78.63569028684392
# R-squared:  -1.015920007748401
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  49.61695340501793
# R-squared:  -0.2719899669963244
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  43.524336917562735
# R-squared:  -0.11579845355254181
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  43.36863799283156
# R-squared:  -0.11180692532400416
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  1.7586856026977135e+279
# R-squared:  -4.508600968446678e+277
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  78.71548906309913
# R-squared:  -1.0179657448565753
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  82.82913739844018
# R-squared:  -1.1234240418945345
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  77.84556421120845
# R-squared:  -0.9956641804172361
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  46.40539067780018
# R-squared:  -0.18965771386392638
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  6573043055467.48
# R-squared:  -168507823341.97736
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  43.36863799283159
# R-squared:  -0.11180692532400482
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  4.231256331556049e+110
# R-squared:  -1.0847331873836203e+109
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  8.322499907114253e+234
# R-squared:  -2.133572429520947e+233
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Optimal combination of hyperparameters:
# Alpha: 0.1
# Gamma: 0.9
# Epsilon: 0.5
# Num Iterations: 10000

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data from the csv file into a dataframe
df = pd.read_csv("wrapper_length.csv")

# Define the state space and action space for the MDP
state_space = np.array(df['anthropometric_measurement'].unique())
action_space = np.array(df['garment_measurement'].unique())

# Define a function to train and evaluate the Q-learning model with a given set of hyperparameters
def train_eval_model(alpha, gamma, epsilon, num_iterations, df):
    # Split the data into training and test data
    X_train, X_test, y_train, y_test = train_test_split(df[['anthropometric_measurement', 'garment_measurement']], df['tolerance'], test_size=0.2, random_state=42)

    # Initialize the Q-Table
    q_table = pd.DataFrame(0.0, index=state_space, columns=action_space, dtype=np.float64)

    for i in range(num_iterations):
        state = X_train['anthropometric_measurement'].sample(1).iloc[0] # select a random state from the training data
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(action_space) # select a random action from the action space
        else:
            action = q_table.loc[state, :].idxmax() # select the action with the highest Q-Value for the current state

        tolerance = y_train[(X_train['anthropometric_measurement'] == state) & (X_train['garment_measurement'] == action)].values

        if len(tolerance) == 0:
            continue
        else:
            reward = np.abs(tolerance[0] - q_table.loc[state, action].astype(float)) # calculate the reward based on the difference between the actual tolerance and the predicted tolerance
            q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value

    # Use the Q-Table to make predictions on the test data
    y_pred = []
    for i in X_test.index:
        state = X_test.loc[i, 'anthropometric_measurement']
        action = q_table.loc[state, :].idxmax()
        y_pred.append(q_table.loc[state, action])

    # Calculate the evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return {'alpha': alpha, 'gamma': gamma, 'epsilon': epsilon, 'num_iterations': num_iterations, 'mse': mse, 'r2': r2}

# Define the hyperparameter grid
param_grid = {'alpha': [0.1, 0.5, 0.9], 'gamma': [0.1, 0.5, 0.9], 'epsilon': [0.1, 0.5,0.9], 'num_iterations': [10000, 20000, 40000]}

# Generate all combinations of hyperparameters
param_list = list(ParameterGrid(param_grid))

# Train and evaluate the model for each set of hyperparameters
results = []
for params in param_list:
    result = train_eval_model(params['alpha'], params['gamma'], params['epsilon'], params['num_iterations'], df)
    result.update({'params':params})
    results.append(result)

# Print the evaluation results for each set of hyperparameters
for result in results:
    print("Parameters: ", result['params'])
    print("Mean Squared Error: ", result['mse'])
    print("R-squared: ", result['r2'])
    print()

# Find the optimal combination of hyperparameters based on the minimum MSE value
optimal_result = min(results, key=lambda x: x['mse'])
optimal_params = optimal_result['params']
print("Optimal combination of hyperparameters:")
print("Alpha:", optimal_params['alpha'])
print("Gamma:", optimal_params['gamma'])
print("Epsilon:", optimal_params['epsilon'])
print("Num Iterations:", optimal_params['num_iterations'])

# Save the results in a dataframe
hyperparameters_combinations = pd.DataFrame(results)

# save into csv file
# hyperparameters_combinations.to_csv('hyperparameters.csv', index=False)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data from the csv file into a dataframe
df = pd.read_csv("armspan.csv")

# Define the state space and action space for the MDP
state_space = np.array(df['anthropometric_measurement'].unique())
action_space = np.array(df['garment_measurement'].unique())

# Define a function to train and evaluate the Q-learning model with a given set of hyperparameters
def train_eval_model(alpha, gamma, epsilon, num_iterations, df):
    # Split the data into training and test data
    X_train, X_test, y_train, y_test = train_test_split(df[['anthropometric_measurement', 'garment_measurement']], df['tolerance'], test_size=0.2, random_state=42)

    # Initialize the Q-Table
    q_table = pd.DataFrame(0.0, index=state_space, columns=action_space, dtype=np.float64)

    for i in range(num_iterations):
        state = X_train['anthropometric_measurement'].sample(1).iloc[0] # select a random state from the training data
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(action_space) # select a random action from the action space
        else:
            action = q_table.loc[state, :].idxmax() # select the action with the highest Q-Value for the current state

        tolerance = y_train[(X_train['anthropometric_measurement'] == state) & (X_train['garment_measurement'] == action)].values

        if len(tolerance) == 0:
            continue
        else:
            reward = np.abs(tolerance[0] - q_table.loc[state, action].astype(float)) # calculate the reward based on the difference between the actual tolerance and the predicted tolerance
            q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action].astype(float)) # update the Q-Table with the new value

    # Use the Q-Table to make predictions on the test data
    y_pred = []
    for i in X_test.index:
        state = X_test.loc[i, 'anthropometric_measurement']
        action = q_table.loc[state, :].idxmax()
        y_pred.append(q_table.loc[state, action])

    # Calculate the evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return {'alpha': alpha, 'gamma': gamma, 'epsilon': epsilon, 'num_iterations': num_iterations, 'mse': mse, 'r2': r2}

# Define the hyperparameter grid
param_grid = {'alpha': [0.1, 0.5, 0.9], 'gamma': [0.1, 0.5, 0.9], 'epsilon': [0.1, 0.5,0.9], 'num_iterations': [10000, 20000, 40000]}

# Generate all combinations of hyperparameters
param_list = list(ParameterGrid(param_grid))

# Train and evaluate the model for each set of hyperparameters
results = []
for params in param_list:
    result = train_eval_model(params['alpha'], params['gamma'], params['epsilon'], params['num_iterations'], df)
    result.update({'params':params})
    results.append(result)

# Print the evaluation results for each set of hyperparameters
for result in results:
    print("Parameters: ", result['params'])
    print("Mean Squared Error: ", result['mse'])
    print("R-squared: ", result['r2'])
    print()

# Find the optimal combination of hyperparameters based on the minimum MSE value
optimal_result = min(results, key=lambda x: x['mse'])
optimal_params = optimal_result['params']
print("Optimal combination of hyperparameters:")
print("Alpha:", optimal_params['alpha'])
print("Gamma:", optimal_params['gamma'])
print("Epsilon:", optimal_params['epsilon'])
print("Num Iterations:", optimal_params['num_iterations'])

# Save the results in a dataframe
hyperparameters_combinations = pd.DataFrame(results)

# save into csv file
# hyperparameters_combinations.to_csv('hyperparameters.csv', index=False)
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  700.2354267884294
# R-squared:  -2.1722728481179363
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  515.8479343674757
# R-squared:  -1.3369431670387262
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  378.5169359306586
# R-squared:  -0.7147932716183818
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  731.120808238673
# R-squared:  -2.312192728247018
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  532.68223182678
# R-squared:  -1.413207495726322
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  198.41372759856634
# R-squared:  0.101127339926811
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  9.49714100480424e+62
# R-squared:  -4.302484763226751e+60
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  398.16265166788565
# R-squared:  -0.8037941536515592
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  380.97201807441166
# R-squared:  -0.7259155172611751
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  239.52235099633637
# R-squared:  -0.08510683909260242
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  365.44134369266254
# R-squared:  -0.6555569853026522
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  354.2855555555555
# R-squared:  -0.6050179773449851
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  4.375029477604873e+53
# R-squared:  -1.9820172888389014e+51
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  1.1235356381788003e+143
# R-squared:  -5.089947555544557e+140
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  9.845530357649412e+267
# R-squared:  -4.4603154073678164e+265
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  inf
# R-squared:  -inf
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  255.4502738619853
# R-squared:  -0.157265023755375
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  250.78985884779246
# R-squared:  -0.13615197028092973
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  228.01520882027123
# R-squared:  -0.032976093791717176
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  145.89987873755746
# R-squared:  0.33903055150236694
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  2.2943491205897275e+30
# R-squared:  -1.0394077678604995e+28
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  8.185706743609828e+30
# R-squared:  -3.7083663939292745e+28
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  2.4184003541359616e+35
# R-squared:  -1.095606632542214e+33
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  6.435550469187784e+57
# R-squared:  -2.915494023164495e+55
#
# Parameters:  {'alpha': 0.9, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  4.059931103344912e+132
# R-squared:  -1.839268439107682e+130
#
# Optimal combination of hyperparameters:
# Alpha: 0.9
# Gamma: 0.5
# Epsilon: 0.9
# Num Iterations: 10000

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data from the csv file into a dataframe
df = pd.read_csv("wrapper_width.csv")

# Define the state space and action space for the MDP
state_space = np.array(df['anthropometric_measurement'].unique())
action_space = np.array(df['garment_measurement'].unique())

# Define a function to train and evaluate the Q-learning model with a given set of hyperparameters
def train_eval_model(alpha, gamma, epsilon, num_iterations, df):
    # Split the data into training and test data
    X_train, X_test, y_train, y_test = train_test_split(df[['anthropometric_measurement', 'garment_measurement']], df['tolerance'], test_size=0.2, random_state=42)

    # Initialize the Q-Table
    q_table = pd.DataFrame(0.0, index=state_space, columns=action_space)

    for i in range(num_iterations):
        state = X_train['anthropometric_measurement'].sample(1).iloc[0] # select a random state from the training data
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(action_space) # select a random action from the action space
        else:
            action = q_table.loc[state, :].idxmax() # select the action with the highest Q-Value for the current state

        tolerance = y_train[(X_train['anthropometric_measurement'] == state) & (X_train['garment_measurement'] == action)].values

        if len(tolerance) == 0:
            continue
        else:
            reward = np.abs(tolerance[0] - q_table.loc[state, action]) # calculate the reward based on the difference between the actual tolerance and the predicted tolerance
            q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value

    # Use the Q-Table to make predictions on the test data
    y_pred = []
    for i in X_test.index:
        state = X_test.loc[i, 'anthropometric_measurement']
        action = q_table.loc[state, :].idxmax()
        y_pred.append(q_table.loc[state, action])

    # Calculate the evaluation metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return {'alpha': alpha, 'gamma': gamma, 'epsilon': epsilon, 'num_iterations': num_iterations, 'mse': mse, 'r2': r2}

# Define the hyperparameter grid
param_grid = {'alpha': [0.1, 0.5, 0.9], 'gamma': [0.1, 0.5, 0.9], 'epsilon': [0.1, 0.5,0.9], 'num_iterations': [10000, 20000, 40000]}

# Generate all combinations of hyperparameters
param_list = list(ParameterGrid(param_grid))

# Train and evaluate the model for each set of hyperparameters
results = []
for params in param_list:
    result = train_eval_model(params['alpha'], params['gamma'], params['epsilon'], params['num_iterations'], df)
    result.update({'params':params})
    results.append(result)

# Print the evaluation results for each set of hyperparameters
for result in results:
    print("Parameters: ", result['params'])
    print("Mean Squared Error: ", result['mse'])
    print("R-squared: ", result['r2'])
    print()
    
# Find the optimal combination of hyperparameters based on the minimum MSE value
optimal_result = min(results, key=lambda x: x['mse'])
optimal_params = optimal_result['params']
print("Optimal combination of hyperparameters:")
print("Alpha:", optimal_params['alpha'])
print("Gamma:", optimal_params['gamma'])
print("Epsilon:", optimal_params['epsilon'])
print("Num Iterations:", optimal_params['num_iterations'])

# Save the results in a dataframe
hyperparameters_combinations = pd.DataFrame(results)

# save into csv file
# hyperparameters_combinations.to_csv('hyperparameters.csv', index=False)
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5588\1547369314.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5588\1547369314.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5588\1547369314.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5588\1547369314.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\user\AppData\Local\Temp\ipykernel_5588\1547369314.py:35: RuntimeWarning: overflow encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# C:\Users\user\AppData\Local\Temp\ipykernel_5588\1547369314.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   q_table.loc[state, action] += alpha * (reward + gamma * q_table.loc[state, :].max() - q_table.loc[state, action]) # update the Q-Table with the new value
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:446: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  5776.101676420497
# R-squared:  -27.502026801315935
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  6588.231564173593
# R-squared:  -31.509461075089497
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  3976.8619427649983
# R-squared:  -18.623724101073048
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  6063.941888706857
# R-squared:  -28.92236700733641
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  3732.526463774496
# R-squared:  -17.41805689491414
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  2903.940592592595
# R-squared:  -13.329420989485701
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  4928.9885919619455
# R-squared:  -23.321968833232248
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  4842.026504704567
# R-squared:  -22.892856625629246
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.1, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  1580.1220407004496
# R-squared:  -6.797072017836064
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  4311.072681151289
# R-squared:  -20.272878488652452
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  2438.1508638927617
# R-squared:  -11.030993421048652
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  2348.622922186143
# R-squared:  -10.58922006993098
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  2634.349698328798
# R-squared:  -11.999131579057723
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  1281.0500205234637
# R-squared:  -5.321308741471676
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  1242.3495444007058
# R-squared:  -5.130342226429631
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  2429.4114419803527
# R-squared:  -10.987868965917896
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  1445.4460143524987
# R-squared:  -6.132516591442878
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.5, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  270.9481655081665
# R-squared:  -0.336986830859753
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  3275.298557300538
# R-squared:  -15.16187742047208
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  3345.3876609144436
# R-squared:  -15.507730319467743
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  2188.1463944831917
# R-squared:  -9.797352725863357
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error:  2266.6052757362777
# R-squared:  -10.184506079725809
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 20000}
# Mean Squared Error:  2424.6607215140193
# R-squared:  -10.964426656616148
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.5, 'num_iterations': 40000}
# Mean Squared Error:  1264.19417914993
# R-squared:  -5.238134020959327
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 10000}
# Mean Squared Error:  1503.8251010950296
# R-squared:  -6.420586710042852
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 20000}
# Mean Squared Error:  1631.7437267992514
# R-squared:  -7.05179791484087
#
# Parameters:  {'alpha': 0.1, 'epsilon': 0.9, 'gamma': 0.9, 'num_iterations': 40000}
# Mean Squared Error:  2115825298089.2515
# R-squared:  -10440486114.267603
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 10000}
# Mean Squared Error:  7147.370324656713
# R-squared:  -34.268517066434256
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 20000}
# Mean Squared Error:  5119.582164358264
# R-squared:  -24.262447968281837
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.1, 'gamma': 0.1, 'num_iterations': 40000}
# Mean Squared Error:  3241.863530932595
# R-squared:  -14.996893133313133
#
# Parameters:  {'alpha': 0.5, 'epsilon': 0.1, 'gamma': 0.5, 'num_iterations': 10000}
# Mean Squared Error: